# %%
import pandas as pd

# %%
pd.DataFrame({'Yes':[1,2,3,4,5],'No':[6,7,8,9,0]})
# Out:
#    Yes  No
# 0    1   6
# 1    2   7
# 2    3   8
# 3    4   9
# 4    5   0

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']}, index= ('Product A','Product B') )
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
# Series
pd.Series([1, 2, 3, 4, 5] , index =['a','b','c','d','f'] , name = 'Alph')
# Out:
# a    1
# b    2
# c    3
# d    4
# f    5
# Name: Alph, dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
wine_reviews = pd.read_csv("../data/winemag-data-130k-v2.csv", index_col = 0)

# %%
wine_reviews.shape
# Out:
# (129971, 13)

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_reviews.country
# Out:
# 0               Italy
# 1            Portugal
# 2                  US
# 3                  US
# 4                  US
# 5               Spain
# 6               Italy
# 7              France
# 8             Germany
# 9              France
# 10                 US
# 11             France
# 12                 US
# 13              Italy
# 14                 US
# 15            Germany
# 16          Argentina
# 17          Argentina
# 18              Spain
# 19                 US
# 20                 US
# 21                 US
# 22              Italy
# 23                 US
# 24              Italy
# 25                 US
# 26              Italy
# 27              Italy
# 28              Italy
# 29                 US
#              ...
# 129941             US
# 129942             US
# 129943          Italy
# 129944         Israel
# 129945             US
# 129946        Germany
# 129947          Italy
# 129948      Argentina
# 129949             US
# 129950             US
# ...

# %%
wine_reviews['country']
# Out:
# 0               Italy
# 1            Portugal
# 2                  US
# 3                  US
# 4                  US
# 5               Spain
# 6               Italy
# 7              France
# 8             Germany
# 9              France
# 10                 US
# 11             France
# 12                 US
# 13              Italy
# 14                 US
# 15            Germany
# 16          Argentina
# 17          Argentina
# 18              Spain
# 19                 US
# 20                 US
# 21                 US
# 22              Italy
# 23                 US
# 24              Italy
# 25                 US
# 26              Italy
# 27              Italy
# 28              Italy
# 29                 US
#              ...
# 129941             US
# 129942             US
# 129943          Italy
# 129944         Israel
# 129945             US
# 129946        Germany
# 129947          Italy
# 129948      Argentina
# 129949             US
# 129950             US
# ...

# %%
wine_reviews['country'][0]
wine_reviews.description.loc[0]
wine_reviews.description.iloc[0]
wine_reviews.description[0]
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
#Indexing in pandas
#index base selection
#wine_reviews.iloc[0]  # select the first row 
wine_reviews.iloc[:,0] # select the first column
# Out:
# 0               Italy
# 1            Portugal
# 2                  US
# 3                  US
# 4                  US
# 5               Spain
# 6               Italy
# 7              France
# 8             Germany
# 9              France
# 10                 US
# 11             France
# 12                 US
# 13              Italy
# 14                 US
# 15            Germany
# 16          Argentina
# 17          Argentina
# 18              Spain
# 19                 US
# 20                 US
# 21                 US
# 22              Italy
# 23                 US
# 24              Italy
# 25                 US
# 26              Italy
# 27              Italy
# 28              Italy
# 29                 US
#              ...
# 129941             US
# 129942             US
# 129943          Italy
# 129944         Israel
# 129945             US
# 129946        Germany
# 129947          Italy
# 129948      Argentina
# 129949             US
# 129950             US
# ...

# %%
wine_reviews.iloc[:3,0]
wine_reviews.iloc[1:3,0]
wine_reviews.iloc[[1,2,3],0] # [row:column]
wine_reviews.iloc[-3:]
# Out:
#        country                                        description  \
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province region_1  \
# 129968                          Kritt      90   30.0   Alsace   Alsace
# 129969                            NaN      90   32.0   Alsace   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace   Alsace
#
#        region_2 taster_name taster_twitter_handle  \
# 129968      NaN  Roger Voss            @vossroger
# 129969      NaN  Roger Voss            @vossroger
# 129970      NaN  Roger Voss            @vossroger
#
#                                                     title         variety  \
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# ...

# %%
#The second paradigm for attribute selection is the one followed by the loc operator: label-based selection.
# or we can say value base selection
wine_reviews.loc[0,'country']
# Out:
# 'Italy'

# %%
wine_reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']] # all rows with three columns detail
cols = ['country', 'variety']
df = wine_reviews.loc[:99, cols]
#or

cols_idx = [0, 11]
df = wine_reviews.iloc[:100, cols_idx]
df
# Out:
#       country                   variety
# 0       Italy               White Blend
# 1    Portugal            Portuguese Red
# 2          US                Pinot Gris
# 3          US                  Riesling
# 4          US                Pinot Noir
# 5       Spain        Tempranillo-Merlot
# 6       Italy                  Frappato
# 7      France            Gewürztraminer
# 8     Germany            Gewürztraminer
# 9      France                Pinot Gris
# 10         US        Cabernet Sauvignon
# 11     France            Gewürztraminer
# 12         US        Cabernet Sauvignon
# 13      Italy         Nerello Mascalese
# 14         US                Chardonnay
# 15    Germany                  Riesling
# 16  Argentina                    Malbec
# 17  Argentina                    Malbec
# 18      Spain         Tempranillo Blend
# 19         US                  Meritage
# 20         US                 Red Blend
# 21         US                Pinot Noir
# ...

# %%
#Manipulating the index
wine_reviews.set_index('title')
# Out:
#                                                         country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                         Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)          Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                US
# St. Julian 2013 Reserve Late Harvest Riesling (...           US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           US
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...        Spain
# Terre di Giurfo 2013 Belsito Frappato (Vittoria)          Italy
# Trimbach 2012 Gewurztraminer (Alsace)                    France
# Heinz Eifel 2013 Shine Gewürztraminer (Rheinhes...      Germany
# Jean-Baptiste Adam 2012 Les Natures Pinot Gris ...       France
# Kirkland Signature 2011 Mountain Cuvée Cabernet...           US
# Leon Beyer 2012 Gewurztraminer (Alsace)                  France
# Louis M. Martini 2012 Cabernet Sauvignon (Alexa...           US
# ...

# %%
#Conditional selection
#wine_reviews.country == 'Italy'
wine_reviews.country.value_counts(dropna = False)
wine_reviews.country.unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
wine_reviews.loc[wine_reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26       Italy  Pretty aromas of yellow flower and stone fruit...
# 27       Italy  Aromas recall ripe dark berry, toast and a whi...
# 28       Italy  Aromas suggest mature berry, scorched earth, a...
# 31       Italy  Merlot and Nero d'Avola form the base for this...
# 32       Italy  Part of the extended Calanìca series, this Gri...
# 37       Italy  This concentrated Cabernet offers aromas of cu...
# 38       Italy  Inky in color, this wine has plump aromas of r...
# 39       Italy  Part of the natural wine movement, this wine i...
# ...

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') & (wine_reviews.points >= 90)]
wine_reviews.loc[(wine_reviews.country == 'Italy') | (wine_reviews.points >= 90)]
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 6             Italy  Here's a bright, informal red that opens with ...
# 13            Italy  This is dominated by oak and oak-driven aromas...
# 22            Italy  Delicate aromas recall white flower and citrus...
# 24            Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26            Italy  Pretty aromas of yellow flower and stone fruit...
# 27            Italy  Aromas recall ripe dark berry, toast and a whi...
# 28            Italy  Aromas suggest mature berry, scorched earth, a...
# 31            Italy  Merlot and Nero d'Avola form the base for this...
# 32            Italy  Part of the extended Calanìca series, this Gri...
# 37            Italy  This concentrated Cabernet offers aromas of cu...
# 38            Italy  Inky in color, this wine has plump aromas of r...
# ...

# %%
#isin is lets you select data whose value "is in" a list of values
wine_reviews.loc[wine_reviews.country.isin(['China','Egypt','Ukraine'])& (wine_reviews.points >= 85)]
# Out:
#         country                                        description  \
# 87995   Ukraine  This nonvintage red dessert wine is made from ...
# 88511   Ukraine  This has aromas of white flowers, especially h...
# 108959  Ukraine  This has aromas of citrus blossom and lemon pi...
# 109989    China  This deep ruby-colored wine features a bouquet...
# 120735  Ukraine  This ruby-red sweet wine is nonvintage made an...
#
#           designation  points  price province region_1 region_2  \
# 87995   Kagor Reserve      85    9.0  Ukraine      NaN      NaN
# 88511         Reserve      88    9.0  Ukraine      NaN      NaN
# 108959        Reserve      85    9.0  Ukraine      NaN      NaN
# 109989   Noble Dragon      89   18.0    China      NaN      NaN
# 120735  Royal Reserve      86    9.0  Ukraine      NaN      NaN
#
#           taster_name taster_twitter_handle  \
# 87995    Jeff Jenssen        @worldwineguys
# 88511    Jeff Jenssen        @worldwineguys
# ...

# %%
wine_reviews.loc[wine_reviews.price.isnull()]
# Out:
#              country                                        description  \
# 0              Italy  Aromas include tropical fruit, broom, brimston...
# 13             Italy  This is dominated by oak and oak-driven aromas...
# 30            France  Red cherry fruit comes laced with light tannin...
# 31             Italy  Merlot and Nero d'Avola form the base for this...
# 32             Italy  Part of the extended Calanìca series, this Gri...
# 50             Italy  This blend of Nero d'Avola and Syrah opens wit...
# 54             Italy  A blend of Nero d'Avola and Nerello Mascalese,...
# 79          Portugal  Grown on the sandy soil of Tejo, the wine is t...
# 137     South Africa  This is great Chenin Blanc, wood fermented but...
# 159            Italy  Intense aromas of ripe red berry, menthol, esp...
# 163           France  Produced from vineyards donated to a charitabl...
# 182            Italy  Loaded with bold, ripe fruit, exotic spice and...
# ...

# %%
wine_reviews['critic'] = 'everyone'
wine_reviews.critic
# Out:
# 0         everyone
# 1         everyone
# 2         everyone
# 3         everyone
# 4         everyone
# 5         everyone
# 6         everyone
# 7         everyone
# 8         everyone
# 9         everyone
# 10        everyone
# 11        everyone
# 12        everyone
# 13        everyone
# 14        everyone
# 15        everyone
# 16        everyone
# 17        everyone
# 18        everyone
# 19        everyone
# 20        everyone
# 21        everyone
# 22        everyone
# 23        everyone
# 24        everyone
# 25        everyone
# 26        everyone
# 27        everyone
# 28        everyone
# 29        everyone
#             ...
# 129941    everyone
# 129942    everyone
# 129943    everyone
# 129944    everyone
# 129945    everyone
# 129946    everyone
# 129947    everyone
# 129948    everyone
# 129949    everyone
# 129950    everyone
# 129951    everyone
# 129952    everyone
# 129953    everyone
# 129954    everyone
# 129955    everyone
# 129956    everyone
# ...

# %%
wine_reviews['index_backwards'] = range(len(wine_reviews), 0, -1)# (start,end,step)
wine_reviews['index_backwards']
# Out:
# 0         129971
# 1         129970
# 2         129969
# 3         129968
# 4         129967
# 5         129966
# 6         129965
# 7         129964
# 8         129963
# 9         129962
# 10        129961
# 11        129960
# 12        129959
# 13        129958
# 14        129957
# 15        129956
# 16        129955
# 17        129954
# 18        129953
# 19        129952
# 20        129951
# 21        129950
# 22        129949
# 23        129948
# 24        129947
# 25        129946
# 26        129945
# 27        129944
# 28        129943
# 29        129942
#            ...
# 129941        30
# 129942        29
# 129943        28
# 129944        27
# 129945        26
# 129946        25
# 129947        24
# 129948        23
# 129949        22
# 129950        21
# 129951        20
# 129952        19
# 129953        18
# 129954        17
# 129955        16
# 129956        15
# 129957        14
# 129958        13
# 129959        12
# 129960        11
# 129961        10
# ...

# %%
# Summary Functions

wine_reviews.points.describe()
wine_reviews.points.mean()
# Out:
# 88.44713820775404

# %%
wine_reviews.taster_name.describe()
wine_reviews.country.describe()
wine_reviews.country.unique()
wine_reviews.country.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
# Maps
wine_review_points_mean = wine_reviews.points.mean()
wine_reviews.points.map(lambda p: p - wine_review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
# 5        -1.447138
# 6        -1.447138
# 7        -1.447138
# 8        -1.447138
# 9        -1.447138
# 10       -1.447138
# 11       -1.447138
# 12       -1.447138
# 13       -1.447138
# 14       -1.447138
# 15       -1.447138
# 16       -1.447138
# 17       -1.447138
# 18       -1.447138
# 19       -1.447138
# 20       -1.447138
# 21       -1.447138
# 22       -1.447138
# 23       -1.447138
# 24       -1.447138
# 25       -1.447138
# 26       -1.447138
# 27       -1.447138
# 28       -1.447138
# 29       -2.447138
#             ...
# 129941    1.552862
# 129942    1.552862
# 129943    1.552862
# 129944    1.552862
# 129945    1.552862
# 129946    1.552862
# 129947    1.552862
# 129948    1.552862
# 129949    1.552862
# 129950    1.552862
# 129951    1.552862
# 129952    1.552862
# 129953    1.552862
# 129954    1.552862
# 129955    1.552862
# 129956    1.552862
# ...

# %%
def remean_points(row):
    row.points = row.points - wine_review_points_mean
    return row

wine_reviews.apply(remean_points, axis = 1)
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
wine_reviews.country + ' - ' + wine_reviews.region_1
# Out:
# 0                          Italy - Etna
# 1                                   NaN
# 2                US - Willamette Valley
# 3              US - Lake Michigan Shore
# 4                US - Willamette Valley
# 5                       Spain - Navarra
# 6                      Italy - Vittoria
# 7                       France - Alsace
# 8                                   NaN
# 9                       France - Alsace
# 10                     US - Napa Valley
# 11                      France - Alsace
# 12                US - Alexander Valley
# 13                         Italy - Etna
# 14                   US - Central Coast
# 15                                  NaN
# 16                 Argentina - Cafayate
# 17                  Argentina - Mendoza
# 18             Spain - Ribera del Duero
# 19                        US - Virginia
# 20                        US - Virginia
# 21                          US - Oregon
# 22                      Italy - Sicilia
# ...

# %%
import pandas as pd
bargain_idx = (wine_reviews.points / wine_reviews.price).idxmax()
bargain_wine = wine_reviews.loc[bargain_idx, 'title']

# %%
bargain_idx
# Out:
# 64590

# %%
wine_reviews.points.idxmax()
# Out:
# 345

# %%
wine_reviews.points.idxmin()
# Out:
# 344

# %%
wine_reviews.price.idxmax()
# Out:
# 80290

# %%
wine_reviews.desc.map(lambda desc:'tropical' in desc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-b1cb20733e3f> in <module>
# ----> 1 wine_reviews.desc.map(lambda desc:'tropical' in desc)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'desc'

# %%
wine_reviews.head(2)

# %%
wine_reviews.description.head(5)
n_trop = wine_reviews.description.map(lambda description: 'tropical' in description).sum()
n_frut = wine_reviews.description.map(lambda description: 'fruity' in description).sum()
descriptor_counts = pd.Series([n_trop, n_frut], index=['tropical', 'fruity'])
descriptor_counts

# %%
def stars(row):
    if row.country == 'Canada':
        return 3
    elif row.points >= 95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1

star_ratings = wine_reviews.apply(stars, axis='columns')
wine_reviews.head()

# %%
# Group by
wine_reviews.groupby('points').points.count()
wine_reviews.groupby('points').points.max()

# %%
wine_reviews.groupby('country').country.count()

# %%
wine_reviews.groupby('points').count()

# %%
wine_reviews.groupby('points')[['country','price']].count()

# %%
wine_reviews.groupby('winery').apply(lambda df: df.title.iloc[0])

# %%
wine_reviews.title.iloc[0]

# %%
#reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
wine_reviews.groupby(['country', 'province'])
wine_reviews.head(10)
wine_reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])

# %%
wine_reviews.loc[wine_reviews.points.idxmin()]

# %%
a = wine_reviews.groupby(['country','province']).price.agg([len, min, max])
a
# Out:
#                                   len   min     max
# country   province
# Argentina Mendoza Province     3264.0   4.0   230.0
#           Other                 536.0   7.0   150.0
# Armenia   Armenia                 2.0  14.0    15.0
# Australia Australia Other       245.0   5.0   130.0
#           New South Wales        85.0   8.0   125.0
#           South Australia      1349.0   7.0   850.0
#           Tasmania               42.0  16.0   130.0
#           Victoria              322.0   9.0   350.0
#           Western Australia     286.0   9.0   250.0
# Austria   Austria                26.0  11.0   150.0
#           Burgenland            672.0   7.0   160.0
#           Carnuntum             103.0  12.0    85.0
#           Eisenberg              16.0  19.0    69.0
#           Kamptal               409.0  12.0    99.0
#           Kremstal              340.0  10.0    90.0
#           Leithaberg             42.0  17.0   111.0
#           Mittelburgenland       23.0  11.0    49.0
# ...

# %%
# Multi indexing
countries_reviewed = wine_reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                                 len
# country   province
# Argentina Mendoza Province     3264
#           Other                 536
# Armenia   Armenia                 2
# Australia Australia Other       245
#           New South Wales        85
#           South Australia      1349
#           Tasmania               42
#           Victoria              322
#           Western Australia     286
# Austria   Austria                26
#           Burgenland            672
#           Carnuntum             103
#           Eisenberg              16
#           Kamptal               409
#           Kremstal              340
#           Leithaberg             42
#           Mittelburgenland       23
#           Neusiedlersee          13
#           Niederösterreich      600
#           Steiermark             20
#           Südburgenland           2
#           Südoststeiermark       37
#           Südsteiermark         109
#           Thermenregion         128
# ...

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#        country             province   len
# 0    Argentina     Mendoza Province  3264
# 1    Argentina                Other   536
# 2      Armenia              Armenia     2
# 3    Australia      Australia Other   245
# 4    Australia      New South Wales    85
# 5    Australia      South Australia  1349
# 6    Australia             Tasmania    42
# 7    Australia             Victoria   322
# 8    Australia    Western Australia   286
# 9      Austria              Austria    26
# 10     Austria           Burgenland   672
# 11     Austria            Carnuntum   103
# 12     Austria            Eisenberg    16
# 13     Austria              Kamptal   409
# 14     Austria             Kremstal   340
# 15     Austria           Leithaberg    42
# 16     Austria     Mittelburgenland    23
# 17     Austria        Neusiedlersee    13
# 18     Austria     Niederösterreich   600
# 19     Austria           Steiermark    20
# 20     Austria        Südburgenland     2
# ...

# %%
# Sorting
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#           country                   province    len
# 179        Greece      Muscat of Kefallonian      1
# 192        Greece              Sterea Ellada      1
# 194        Greece                     Thraki      1
# 354  South Africa                 Paardeberg      1
# 40         Brazil           Serra do Sudeste      1
# 114         Egypt                      Egypt      1
# 316        Serbia                   Pocerina      1
# 112        Cyprus         Pitsilia Mountains      1
# 110        Cyprus                    Lemesos      1
# 301      Portugal              Vinho da Mesa      1
# 48         Canada               Canada Other      1
# 109        Cyprus                   Kathikas      1
# 380   Switzerland                     Ticino      1
# 331  South Africa               Cape Agulhas      1
# 303       Romania          Dealurile Hușilor      1
# 103       Croatia  Middle and South Dalmatia      1
# 101       Croatia                        Krk      1
# ...

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#           country                   province    len
# 392            US                 California  36247
# 415            US                 Washington   8639
# 118        France                   Bordeaux   5941
# 227         Italy                    Tuscany   5897
# 409            US                     Oregon   5373
# 119        France                   Burgundy   3980
# 375         Spain             Northern Spain   3851
# 224         Italy                   Piedmont   3729
# 0       Argentina           Mendoza Province   3264
# 228         Italy                     Veneto   2716
# 406            US                   New York   2688
# 116        France                     Alsace   2440
# 222         Italy         Northeastern Italy   2138
# 123        France               Loire Valley   1856
# 225         Italy          Sicily & Sardinia   1797
# 120        France                  Champagne   1613
# 126        France           Southwest France   1503
# ...

# %%
countries_reviewed.sort_index()
# Out:
#        country             province   len
# 0    Argentina     Mendoza Province  3264
# 1    Argentina                Other   536
# 2      Armenia              Armenia     2
# 3    Australia      Australia Other   245
# 4    Australia      New South Wales    85
# 5    Australia      South Australia  1349
# 6    Australia             Tasmania    42
# 7    Australia             Victoria   322
# 8    Australia    Western Australia   286
# 9      Austria              Austria    26
# 10     Austria           Burgenland   672
# 11     Austria            Carnuntum   103
# 12     Austria            Eisenberg    16
# 13     Austria              Kamptal   409
# 14     Austria             Kremstal   340
# 15     Austria           Leithaberg    42
# 16     Austria     Mittelburgenland    23
# 17     Austria        Neusiedlersee    13
# 18     Austria     Niederösterreich   600
# 19     Austria           Steiermark    20
# 20     Austria        Südburgenland     2
# ...

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country                   province    len
# 1    Argentina                      Other    536
# 0    Argentina           Mendoza Province   3264
# 2      Armenia                    Armenia      2
# 6    Australia                   Tasmania     42
# 4    Australia            New South Wales     85
# 3    Australia            Australia Other    245
# 8    Australia          Western Australia    286
# 7    Australia                   Victoria    322
# 5    Australia            South Australia   1349
# 20     Austria              Südburgenland      2
# 32     Austria  Österreichischer Perlwein      4
# 17     Austria              Neusiedlersee     13
# 12     Austria                  Eisenberg     16
# 29     Austria        Weinland Österreich     18
# 19     Austria                 Steiermark     20
# 16     Austria           Mittelburgenland     23
# 9      Austria                    Austria     26
# 31     Austria     Wiener Gemischter Satz     28
# ...

# %% [raw]
# Who are the most common wine reviewers in the dataset? Create a Series whose index is the taster_twitter_handle category from the dataset, and whose values count how many reviews each person wrote.

# %%
wine_reviews.groupby('taster_twitter_handle').description.agg([len])
# Out:
#                          len
# taster_twitter_handle
# @AnneInVino             3685
# @JoeCz                  5147
# @bkfiona                  27
# @gordone_cellars        4177
# @kerinokeefe           10776
# @laurbuzz               1835
# @mattkettmann           6332
# @paulgwine              9532
# @suskostrzewa           1085
# @vboone                 9537
# @vossroger             25514
# @wawinereport           4966
# @wineschach            15134
# @winewchristina            6
# @worldwineguys          1005

# %%
wine_reviews.taster_twitter_handle.value_counts()
# Out:
# @vossroger          25514
# @wineschach         15134
# @kerinokeefe        10776
# @vboone              9537
# @paulgwine           9532
# @mattkettmann        6332
# @JoeCz               5147
# @wawinereport        4966
# @gordone_cellars     4177
# @AnneInVino          3685
# @laurbuzz            1835
# @suskostrzewa        1085
# @worldwineguys       1005
# @bkfiona               27
# @winewchristina         6
# Name: taster_twitter_handle, dtype: int64

# %%
type(wine_reviews.taster_twitter_handle.value_counts())
# Out:
# pandas.core.series.Series

# %%
wine_reviews.groupby('taster_twitter_handle').size()
wine_reviews.groupby('taster_twitter_handle').count()
reviews_written = wine_reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()
# Out:
#                        country  description  designation  points  price  \
# taster_twitter_handle
# @AnneInVino               3676         3685         3130    3685   3398
# @JoeCz                    5145         5147         3428    5147   5012
# @bkfiona                    27           27           17      27     27
# @gordone_cellars          4177         4177         2660    4177   4171
# @kerinokeefe             10776        10776         7549   10776   9874
# @laurbuzz                 1832         1835         1268    1835   1713
# @mattkettmann             6332         6332         4568    6332   6237
# @paulgwine                9531         9532         6482    9532   9498
# @suskostrzewa             1080         1085          682    1085   1073
# @vboone                   9537         9537         6764    9537   9507
# @vossroger               25512        25514        17963   25514  20172
# @wawinereport             4966         4966         3550    4966   4925
# ...

# %% [raw]
# What is the best wine I can buy for a given amount of money? Create a Series whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that 4.0 dollars is at the top and 3300.0 dollars is at the bottom).

# %%
wine_reviews.groupby(['price','points']).price.count()
wine_reviews.groupby(['price']).points.max().sort_index()
# Out:
# price
# 4.0        86
# 5.0        87
# 6.0        88
# 7.0        91
# 8.0        91
# 9.0        91
# 10.0       91
# 11.0       92
# 12.0       93
# 13.0       94
# 14.0       94
# 15.0       93
# 16.0       94
# 17.0       93
# 18.0       94
# 19.0       94
# 20.0       96
# 21.0       94
# 22.0       95
# 23.0       94
# 24.0       95
# 25.0       95
# 26.0       95
# 27.0       96
# 28.0       96
# 29.0       96
# 30.0       96
# 31.0       95
# 32.0       96
# 33.0       94
#          ...
# 698.0      97
# 710.0      95
# 750.0      92
# 757.0      98
# 764.0      94
# 767.0      96
# 770.0      96
# 775.0      98
# 780.0      91
# 790.0      87
# 800.0      99
# 820.0      96
# 848.0     100
# 850.0      99
# 886.0      97
# 900.0      94
# 932.0      97
# 973.0      95
# 980.0      94
# 1000.0     97
# 1100.0     97
# 1125.0     94
# 1200.0     96
# 1300.0     96
# 1500.0    100
# 1900.0     98
# 2000.0     97
# 2013.0     91
# 2500.0     96
# 3300.0     88
# ...

# %% [raw]
# What are the minimum and maximum prices for each variety of wine? Create a DataFrame whose index is the variety category from the dataset and whose values are the min and max values thereof.

# %%
wine_reviews.groupby('variety').price.agg([min,max])
# Out:
#                          min    max
# variety
# Abouriou                15.0   75.0
# Agiorgitiko             10.0   66.0
# Aglianico                6.0  180.0
# Aidani                  27.0   27.0
# Airen                    8.0   10.0
# Albana                  12.0   50.0
# Albanello               20.0   20.0
# Albariño                10.0   75.0
# Albarossa               40.0   40.0
# Aleatico                25.0   55.0
# Alfrocheiro             11.0   50.0
# Alicante                10.0   30.0
# Alicante Bouschet        7.0  150.0
# Aligoté                 13.0   36.0
# Alsace white blend      10.0   98.0
# Altesse                 15.0   19.0
# Alvarelhão              18.0   24.0
# Alvarinho                9.0   75.0
# Alvarinho-Chardonnay     9.0   15.0
# Ansonica                22.0   30.0
# Antão Vaz               11.0   30.0
# Apple                   25.0   33.0
# Aragonez                10.0   35.0
# Aragonês                14.0   70.0
# Argaman                 36.0   48.0
# ...

# %% [raw]
# What are the most expensive wine varieties? Create a variable sorted_varieties containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
variety_price = wine_reviews.groupby('variety').price.agg([min,max])
variety_price.sort_values(by = ['min','max'], ascending = False)
# Out:
#                                   min     max
# variety
# Ramisco                         495.0   495.0
# Terrantez                       236.0   236.0
# Francisa                        160.0   160.0
# Rosenmuskateller                150.0   150.0
# Tinta Negra Mole                112.0   112.0
# Pignolo                          70.0    70.0
# Syrah-Cabernet Franc             60.0    69.0
# Garnacha-Cariñena                57.0    57.0
# Doña Blanca                      53.0    53.0
# Cercial                          50.0    50.0
# Mavrotragano                     50.0    50.0
# Sercial                          50.0    50.0
# Pugnitello                       49.0    49.0
# Malbec-Cabernet                  45.0   165.0
# Tinta del Pais                   45.0    50.0
# Touriga                          45.0    46.0
# Babosa Negro                     45.0    45.0
# Cabernet Sauvignon-Barbera       45.0    45.0
# Syrah-Grenache-Viognier          45.0    45.0
# ...

# %% [raw]
# Create a Series whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the taster_name and points columns.

# %%
#wine_reviews.taster_name
wine_reviews.groupby('taster_name').points.agg([max,min])
reviwer_mean_rating = wine_reviews.groupby('taster_name').points.mean()
reviwer_mean_rating.describe()
# Out:
# count    19.000000
# mean     88.233026
# std       1.243610
# min      85.855422
# 25%      87.323501
# 50%      88.536235
# 75%      88.975256
# max      90.562551
# Name: points, dtype: float64

# %% [raw]
# What combination of countries and varieties are most common? Create a Series whose index is a MultiIndexof {country, variety} pairs. For example, a pinot noir produced in the US should map to {"US", "Pinot Noir"}. Sort the values in the Series in descending order based on wine count.

# %%
wine_reviews.groupby(['country','variety']).country.agg([len])
# Out:
#                                               len
# country   variety
# Argentina Barbera                               1
#           Bonarda                             105
#           Bordeaux-style Red Blend             89
#           Bordeaux-style White Blend            1
#           Cabernet Blend                        8
#           Cabernet Franc                       64
#           Cabernet Franc-Cabernet Sauvignon     3
#           Cabernet Franc-Malbec                 4
#           Cabernet Sauvignon                  540
#           Cabernet Sauvignon-Cabernet Franc     1
#           Cabernet Sauvignon-Malbec            12
#           Cabernet Sauvignon-Merlot             5
#           Cabernet Sauvignon-Shiraz             3
#           Cabernet Sauvignon-Syrah              2
#           Cabernet-Malbec                       1
#           Cabernet-Syrah                        1
#           Champagne Blend                       8
# ...

# %%
wine_reviews.groupby(['country','variety']).size().sort_values(ascending = False)
# Out:
# country     variety
# US          Pinot Noir                    9885
#             Cabernet Sauvignon            7315
#             Chardonnay                    6801
# France      Bordeaux-style Red Blend      4725
# Italy       Red Blend                     3624
# US          Syrah                         3244
#             Red Blend                     2972
# France      Chardonnay                    2808
# Italy       Nebbiolo                      2736
# US          Zinfandel                     2711
# Portugal    Portuguese Red                2466
# US          Merlot                        2311
# Italy       Sangiovese                    2265
# US          Sauvignon Blanc               2163
# France      Pinot Noir                    1966
#             Rosé                          1923
# US          Bordeaux-style Red Blend      1824
# Germany     Riesling                      1790
# US          Riesling                      1753
# ...

# %%
# Data types
wine_reviews.price.dtype
# Out:
# dtype('float64')

# %%
wine_reviews.dtypes   # dtypes is used instead dtype
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
wine_reviews.points.astype('float64')
wine_reviews.index.dtype
# Out:
# dtype('int64')

# %%
# Missing data

# %%
wine_reviews[pd.isnull(wine_reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# 11150      NaN  A blend of 85% Melnik, 10% Grenache Noir and 5...
# 11348      NaN  Light and fruity, this is a wine that has some...
# 14030      NaN  This Furmint, grown in marl soils, has aromas ...
# 16000      NaN  Jumpy, jammy aromas of foxy black fruits are s...
# 16749      NaN  Winemaker: Bartho Eksteen. This wooded Sauvy s...
# 18075      NaN  Delicate white flowers and a spin of lemon pee...
# 26485      NaN  This wine has aromas of black berry, dried red...
# 26486      NaN  Aromas of green apple and white flowers prepar...
# ...

# %%
wine_reviews.country.isnull()
wine_reviews.country.isnull().sum()
# Out:
# 63

# %%
#wine_reviews.country.fillna("Unknown")
wine_reviews.region_2.fillna("Unknown") # replacing the missing value with any keyword--->>> backfill strategy
wine_reviews.region_2.isnull().sum()
# Out:
# 79460

# %%
# Replacing method
wine_reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0                @kerino
# 1             @vossroger
# 2            @paulgwine
# 3                    NaN
# 4            @paulgwine
# 5            @wineschach
# 6                @kerino
# 7             @vossroger
# 8                    NaN
# 9             @vossroger
# 10               @vboone
# 11            @vossroger
# 12               @vboone
# 13               @kerino
# 14         @mattkettmann
# 15                   NaN
# 16           @wineschach
# 17           @wineschach
# 18           @wineschach
# 19                   NaN
# 20                   NaN
# 21           @paulgwine
# 22               @kerino
# 23         @mattkettmann
# 24               @kerino
# 25               @vboone
# 26               @kerino
# 27               @kerino
# 28               @kerino
# 29               @vboone
#                ...
# 129941           @vboone
# 129942           @vboone
# 129943           @kerino
# 129944    @worldwineguys
# 129945     @mattkettmann
# 129946               NaN
# ...

# %%
wine_reviews.region_1.fillna('Unknown').value_counts().sort_values(ascending = False)
# Out:
# Montlouis-sur-Loire                            1
# Est! Est!! Est!!! di Montefiascone             1
# Clairette de Bellegarde                        1
# Catalanesca del Monte Somma                    1
# Mendocino-Amador                               1
# Valpolicella Valpantena Superiore              1
# Barossa-Langhorne Creek                        1
# Del Veneto                                     1
# Nasco di Cagliari                              1
# Gutturnio Classico Superiore                   1
# Falanghina del Molise                          1
# Currency Creek-McLaren Vale                    1
# Côtes de Saint-Mont                            1
# Rosso di Cerignola                             1
# Vallée du Paradis                              1
# Apremont                                       1
# Napa Valley-Paso Robles                        1
# Lambrusco Salamino di Santa Croce              1
# Vin de Pays de l'Atlantique                    1
# ...

# %%
# Renaming

# %%
wine_reviews.rename(columns={'points': 'score'})
wine_reviews.rename(columns = {'region_1': 'region','region_2': 'locale'})
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
wine_reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                  country                                        description  \
# firstEntry         Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry     Portugal  This is ripe and fruity, a wine that is smooth...
# 2                     US  Tart and snappy, the flavors of lime flesh and...
# 3                     US  Pineapple rind, lemon pith and orange blossom ...
# 4                     US  Much like the regular bottling from 2012, this...
# 5                  Spain  Blackberry and raspberry aromas show a typical...
# 6                  Italy  Here's a bright, informal red that opens with ...
# 7                 France  This dry and restrained wine offers spice in p...
# 8                Germany  Savory dried thyme notes accent sunnier flavor...
# 9                 France  This has great depth of flavor with its fresh ...
# 10                    US  Soft, supple plum envelopes an oaky structure ...
# ...

# %%
wine_reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
wine_reviews.rename_axis("rows", axis='rows').rename_axis("columns", axis='columns')
# Out:
# fields      country                                        description  \
# wines
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
wine_reviews.rename_axis("rows", axis='rows').rename_axis("columns", axis='columns')
# Out:
# columns      country                                        description  \
# rows
# 0              Italy  Aromas include tropical fruit, broom, brimston...
# 1           Portugal  This is ripe and fruity, a wine that is smooth...
# 2                 US  Tart and snappy, the flavors of lime flesh and...
# 3                 US  Pineapple rind, lemon pith and orange blossom ...
# 4                 US  Much like the regular bottling from 2012, this...
# 5              Spain  Blackberry and raspberry aromas show a typical...
# 6              Italy  Here's a bright, informal red that opens with ...
# 7             France  This dry and restrained wine offers spice in p...
# 8            Germany  Savory dried thyme notes accent sunnier flavor...
# 9             France  This has great depth of flavor with its fresh ...
# 10                US  Soft, supple plum envelopes an oaky structure ...
# 11            France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
# Combining ___>>>> concat(), join(), and merge()

# %%
canadian_youtube = pd.read_csv("../data/CAvideos.csv")
british_youtube = pd.read_csv("../data/GBvideos.csv")

# %%
pd.concat([canadian_youtube, british_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# 5      0yIWz1XEeyc      17.14.11
# 6      _uM5kFfkhB8      17.14.11
# 7      2kyS6SvSYSE      17.14.11
# 8      JzCsM1vtn78      17.14.11
# 9      43sm-QwLcx4      17.14.11
# 10     H1KBHFXm2Bg      17.14.11
# 11     U3xLOo-CNwo      17.14.11
# 12     FyZMnhUtLfE      17.14.11
# 13     7MxiQ4v0EnE      17.14.11
# 14     LUzsOyWp9lw      17.14.11
# 15     AS9-ITLhQxo      17.14.11
# 16     gifPYwArCVQ      17.14.11
# 17     8NHA23f7LvU      17.14.11
# 18     fy-CuCzaPp8      17.14.11
# 19     kzwfHumJyYc      17.14.11
# 20     nc99ccSXST0      17.14.11
# 21     puqaWrEC7tY      17.14.11
# 22     6H3wVsceoS0      17.14.11
# 23     PRlmRnU9qts      17.14.11
# 24     ZhhXLMbZ1rQ      17.14.11
# 25     wuf2KinLxZ8      17.14.11
# 26     aVTAU_4i9AY      17.14.11
# ...

# %%
canadian_youtube
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# 5      0yIWz1XEeyc      17.14.11
# 6      _uM5kFfkhB8      17.14.11
# 7      2kyS6SvSYSE      17.14.11
# 8      JzCsM1vtn78      17.14.11
# 9      43sm-QwLcx4      17.14.11
# 10     H1KBHFXm2Bg      17.14.11
# 11     U3xLOo-CNwo      17.14.11
# 12     FyZMnhUtLfE      17.14.11
# 13     7MxiQ4v0EnE      17.14.11
# 14     LUzsOyWp9lw      17.14.11
# 15     AS9-ITLhQxo      17.14.11
# 16     gifPYwArCVQ      17.14.11
# 17     8NHA23f7LvU      17.14.11
# 18     fy-CuCzaPp8      17.14.11
# 19     kzwfHumJyYc      17.14.11
# 20     nc99ccSXST0      17.14.11
# 21     puqaWrEC7tY      17.14.11
# 22     6H3wVsceoS0      17.14.11
# 23     PRlmRnU9qts      17.14.11
# 24     ZhhXLMbZ1rQ      17.14.11
# 25     wuf2KinLxZ8      17.14.11
# 26     aVTAU_4i9AY      17.14.11
# ...

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03       EXEaMjFeiEk
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R... 17.20.12       bYvQmusLaxw
#                                                    17.21.12       bYvQmusLaxw
# #1 WORLD RANKED 1463 SOLO WINS! - FORTNITE BATT... 18.18.01       xQ4Q5b2WwO8
# #1 WORLD RECORD 3,288 SOLO WINS                    18.22.05       vrniSczvTjQ
# #1 World Ranked - 1,700 Solo Wins -  New Minigu... 18.03.02       OL7iIR8e2-k
# #1 World Record 3,225 Solo Wins | Fortnite Live... 18.15.05       j2wuWo19i3I
# #1 World Record 3,359 Solo Wins | Fortnite Live... 18.05.06       Pgf7tfu2ujw
# ...

# %% [raw]
# The lsuffix and rsuffix parameters are necessary here because the data has the same column names in both British and Canadian datasets.
