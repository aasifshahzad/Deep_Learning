# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'C:/Users/Asif/QUARTER 2/Deep Learning/DATA/weight-height.csv' 
data = pd.read_csv(path)

# %%
import os

# %%
os.getcwd() # gives current working directory as can be checked by command 'pwd'
# Out:
# 'C:\\Users\\Asif\\QUARTER 2\\Deep Learning\\ CLASS'

# %%
os.mkdir('NewFolder')

# %%
data.info()
data.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
# Gender    10000 non-null object
# Height    10000 non-null float64
# Weight    10000 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473

# %%
X = data.Height.values   # input data
y_true = data.Weight.values # output , answer

# %%
print(X[:5],y_true[:5])
# Out:
# [73.84701702 68.78190405 74.11010539 71.7309784  69.88179586] [241.89356318 162.31047252 212.74085556 220.0424703  206.34980062]

# %%
def line(x, w=0, b=0):   #line equation
    return x * w + b

# Cost function

def mean_square_error(y_true,y_pred):
    s = (y_true - y_pred)**2
    return np.sqrt(s.mean())

# %%
plt.figure(figsize=(10,5))
ax1 = plt.subplot(121) # rows , columns, select column
data.plot(kind = "scatter",
       x = 'Height',
       y = 'Weight',
       title = "Height vs Weight",
       ax = ax1)

bs = [-150,-100,-50,0,50,100,150]
mses = []
for b in bs:
    y_pred = line(X, w = 2, b = b)
    mse = mean_square_error(y_true,y_pred)
    mses.append(mse)
    plt.plot(X, y_pred)
    
ax2 = plt.subplot(122)
plt.plot(bs, mses,'-d')
plt.title('Cost Function for each Line')
plt.xlabel('b')
plt.ylabel('mse')
plt.show()

# %%
pip install tensorflow
# Out:
# ...
#   Created wheel for absl-py: filename=absl_py-0.9.0-py3-none-any.whl size=121934 sha256=75b809a842885d3ffc233003c8ee171f87b62a72c572502828aad7b5734ce1ed
#   Stored in directory: c:\users\asif\appdata\local\pip\cache\wheels\cc\af\1a\498a24d0730ef484019e007bb9e8cef3ac00311a672c049a3e
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=3fd2622651db124b7eabf2b9610aadc2d033726a09b433c0ba416debe5a5c107
#   Stored in directory: c:\users\asif\appdata\local\pip\cache\wheels\3f\e3\ec\8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built absl-py termcolor
# ...
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.9.0
#     Uninstalling h5py-2.9.0:
#       Successfully uninstalled h5py-2.9.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.2.1
#     Uninstalling scipy-1.2.1:
#       Successfully uninstalled scipy-1.2.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 20.0.2
#     Uninstalling pip-20.0.2:
#       Successfully uninstalled pip-20.0.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c60f27033de8> in <module>
#       1 import tensorflow
# ----> 2 tensorflow__version__
#
# NameError: name 'tensorflow__version__' is not defined

# %%
tensorflow.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X.shape
# Out:
# (10000,)

# %%
model = Sequential()
model.add(Dense(1, input_shape = (1,)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.8), 'mean_squared_error',['accuracy']) # lr-->> learning rate

# %%
model.fit(X,y_true,epochs = 45)
# Out:
# Epoch 1/45
# 313/313 [==============================] - 2s 7ms/step - loss: 204.1266 - accuracy: 0.0000e+00
# Epoch 2/45
# 313/313 [==============================] - 1s 4ms/step - loss: 170.1178 - accuracy: 0.0000e+00
# Epoch 3/45
# 313/313 [==============================] - 1s 3ms/step - loss: 182.0466 - accuracy: 0.0000e+00
# Epoch 4/45
# 313/313 [==============================] - 1s 3ms/step - loss: 173.7985 - accuracy: 0.0000e+00
# Epoch 5/45
# 313/313 [==============================] - 1s 3ms/step - loss: 171.7522 - accuracy: 0.0000e+00
# Epoch 6/45
# 313/313 [==============================] - 1s 3ms/step - loss: 171.7565 - accuracy: 0.0000e+00
# Epoch 7/45
# 313/313 [==============================] - 1s 2ms/step - loss: 187.2581 - accuracy: 0.0000e+00
# Epoch 8/45
# 313/313 [==============================] - 1s 2ms/step - loss: 181.6008 - accuracy: 0.0000e+00
# Epoch 9/45
# 313/313 [==============================] - 1s 2ms/step - loss: 175.8236 - accuracy: 0.0000e+00
# ...

# %%
y_pred_deep_learning = model.predict(X)
y_pred_deep_learning
# Out:
# array([[219.60202],
#        [180.46841],
#        [221.63467],
#        ...,
#        [142.50293],
#        [182.41794],
#        [127.63983]], dtype=float32)

# %%
data.plot(kind = 'Scatter',
         x = 'Height',
         y = 'Weight',
         title = 'Height Vs Weight by Deep Learning')
plt.plot(X,y_pred_deep_learning,color = 'green', linewidth = '5')

# %%
w, b = model.get_weights()
print(w,b)
# Out:
# [[7.7261157]] [-350.94858]

# %%
model.predict([[100]])
# Out:
# array([[421.663]], dtype=float32)

# %%
data.plot(kind = 'Scatter',
         x = 'Height',
         y = 'Weight',
         title = 'Height Vs Weight by Deep Learning')
plt.plot(X,y_pred_deep_learning,color = 'green', linewidth = '5')
i = 150
plt.scatter(i,model.predict([[i]]), color = 'r')

# %%
# the value of 'w' and 'b' are find by the deeplearning
plt.figure(figsize=(10,5))
ax1 = plt.subplot(121) # rows , columns, select column
data.plot(kind = "scatter",
       x = 'Height',
       y = 'Weight',
       title = "Height vs Weight",
       ax = ax1)

#[[7.704267]] [-348.9165]
y_pred = line(X, w = 7.704267, b = -348.9165)
plt.plot(X, y_pred,color= 'r')
plt.show()

# %% [raw]
# working on colab:
# go to coloab.com
# import tensorflow
# tensorflow.__version__
# !pip install --upgrade tensorflow
# df = pd.read_csv("https://github.com/EnggQasim/UIT/blob/master/Deep_Learning/Chapter1/data/weight-height.csv", encoding = 'cp1252'or 'utf-8')

# %%
df = pd.read_csv("https://github.com/EnggQasim/UIT/blob/master/Deep_Learning/Chapter1/data/weight-height.csv", encoding = 'cp1252'or 'utf-8')
